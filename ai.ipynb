# %%
l = [1,2,54,98,0]
l.sort()

print(l)
l.append(9)
print(l)
# Out:
# [0, 1, 2, 54, 98]
# [0, 1, 2, 54, 98, 9]

# %%
l = [1,2,54,98,0,54,54,54]
l.remove(2)  
print(l)
l.sort(reverse=True)
print(l)
# Out:
# [1, 54, 98, 0, 54, 54, 54]
# [98, 54, 54, 54, 54, 1, 0]

# %%
l.reverse()
print(l)
# Out:
# [0, 1, 54, 54, 54, 54, 98]

# %%
l.count(54)
# Out:
# 4

# %%
l.index(54)
# Out:
# 2
